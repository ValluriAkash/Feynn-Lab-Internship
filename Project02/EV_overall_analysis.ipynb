# %% [markdown]
# **Importing libraries**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Importing datasets**

# %% [markdown]
# dataset for geographic analysis of electric vehicles

# %%
ev_data = pd.read_csv('/content/EVStats.csv')
ev_data.head()
# Out:
#    Sl. No                      State  \
# 0       1                  Meghalaya
# 1       2                   Nagaland
# 2       3                    Manipur
# 3       4                    Tripura
# 4       5  Andaman & Nicobar islands
#
#    Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules  \
# 0                                                  0
# 1                                                  0
# 2                                                 16
# 3                                                 28
# 4                                                  0
#
#    Two Wheelers (Category L2 (CMVR))  \
# 0                                  0
# 1                                 20
# 2                                  8
# 3                                  9
# 4                                  0
#
#    Two Wheelers (Max power not exceeding 250 Watts)  \
# 0                                                 0
# 1                                                 3
# ...

# %% [markdown]
# **Data Preprocessing**

# %%
ev_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 10 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Sl. No                                                              30 non-null     int64
#  1   State                                                               30 non-null     object
#  2   Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules  30 non-null     int64
#  3   Two Wheelers (Category L2 (CMVR))                                   30 non-null     int64
#  4   Two Wheelers (Max power not exceeding 250 Watts)                    30 non-null     int64
#  5   Three Wheelers (Category L5 slow speed as per CMVR)                 30 non-null     int64
#  6   Three Wheelers (Category L5 as per CMVR)                            30 non-null     int64
# ...

# %%
ev_data.describe()
# Out:
#           Sl. No  \
# count  30.000000
# mean   15.500000
# std     8.803408
# min     1.000000
# 25%     8.250000
# 50%    15.500000
# 75%    22.750000
# max    30.000000
#
#        Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules  \
# count                                          30.000000
# mean                                          918.300000
# std                                          1482.441466
# min                                             0.000000
# 25%                                            19.000000
# 50%                                           447.500000
# 75%                                           762.500000
# max                                          7182.000000
#
#        Two Wheelers (Category L2 (CMVR))  \
# count                          30.000000
# mean                          468.966667
# std                           625.711098
# min                             0.000000
# 25%                            18.500000
# ...

# %%
ev_data.shape
# Out:
# (30, 10)

# %%
ev_data.columns
# Out:
# Index(['Sl. No', 'State',
#        'Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules',
#        'Two Wheelers (Category L2 (CMVR))',
#        'Two Wheelers (Max power not exceeding 250 Watts)',
#        'Three Wheelers (Category L5 slow speed as per CMVR)',
#        'Three Wheelers (Category L5 as per CMVR)',
#        'Passenger Cars (Category M1 as per CMVR)', 'Buses', 'Total in state'],
#       dtype='object')

# %%
ev_data.isnull().sum()
# Out:
# Sl. No                                                                0
# State                                                                 0
# Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules    0
# Two Wheelers (Category L2 (CMVR))                                     0
# Two Wheelers (Max power not exceeding 250 Watts)                      0
# Three Wheelers (Category L5 slow speed as per CMVR)                   0
# Three Wheelers (Category L5 as per CMVR)                              0
# Passenger Cars (Category M1 as per CMVR)                              0
# Buses                                                                 0
# Total in state                                                        0
# dtype: int64

# %% [markdown]
# dataset for demographic, behavioural and psychographic analysis

# %%
customer_data = pd.read_csv("/content/Indian automobile buying behaviour study.csv")
customer_data.head()
# Out:
#    Age Profession Marrital Status      Education  No of Dependents  \
# 0   27   Salaried          Single  Post Graduate                 0
# 1   35   Salaried         Married  Post Graduate                 2
# 2   45   Business         Married       Graduate                 4
# 3   41   Business         Married  Post Graduate                 3
# 4   31   Salaried         Married  Post Graduate                 2
#
#   Personal loan House Loan Wife Working   Salary  Wife Salary  Total Salary  \
# 0           Yes         No           No   800000            0        800000
# 1           Yes        Yes          Yes  1400000       600000       2000000
# 2           Yes        Yes           No  1800000            0       1800000
# 3            No         No          Yes  1600000       600000       2200000
# 4           Yes         No          Yes  1800000       800000       2600000
#
#      Make    Price
# 0     i20   800000
# 1    Ciaz  1000000
# 2  Duster  1200000
# 3    City  1200000
# ...

# %%
customer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               99 non-null     int64
#  1   Profession        99 non-null     object
#  2   Marrital Status   99 non-null     object
#  3   Education         99 non-null     object
#  4   No of Dependents  99 non-null     int64
#  5   Personal loan     99 non-null     object
#  6   House Loan        99 non-null     object
#  7   Wife Working      99 non-null     object
#  8   Salary            99 non-null     int64
#  9   Wife Salary       99 non-null     int64
#  10  Total Salary      99 non-null     int64
#  11  Make              99 non-null     object
#  12  Price             99 non-null     int64
# dtypes: int64(6), object(7)
# memory usage: 10.2+ KB

# %% [markdown]
# **Data preprocessing**

# %%
customer_data.describe()
# Out:
#              Age  No of Dependents        Salary   Wife Salary  Total Salary  \
# count  99.000000         99.000000  9.900000e+01  9.900000e+01  9.900000e+01
# mean   36.313131          2.181818  1.736364e+06  5.343434e+05  2.270707e+06
# std     6.246054          1.335265  6.736217e+05  6.054450e+05  1.050777e+06
# min    26.000000          0.000000  2.000000e+05  0.000000e+00  2.000000e+05
# 25%    31.000000          2.000000  1.300000e+06  0.000000e+00  1.550000e+06
# 50%    36.000000          2.000000  1.600000e+06  5.000000e+05  2.100000e+06
# 75%    41.000000          3.000000  2.200000e+06  9.000000e+05  2.700000e+06
# max    51.000000          4.000000  3.800000e+06  2.100000e+06  5.200000e+06
#
#               Price
# count  9.900000e+01
# mean   1.194040e+06
# std    4.376955e+05
# min    1.100000e+05
# 25%    8.000000e+05
# 50%    1.200000e+06
# 75%    1.500000e+06
# max    3.000000e+06

# %%
customer_data.shape
# Out:
# (99, 13)

# %%
customer_data.columns
# Out:
# Index(['Age', 'Profession', 'Marrital Status', 'Education', 'No of Dependents',
#        'Personal loan', 'House Loan', 'Wife Working', 'Salary', 'Wife Salary',
#        'Total Salary', 'Make', 'Price'],
#       dtype='object')

# %%
customer_data.isnull().sum()
# Out:
# Age                 0
# Profession          0
# Marrital Status     0
# Education           0
# No of Dependents    0
# Personal loan       0
# House Loan          0
# Wife Working        0
# Salary              0
# Wife Salary         0
# Total Salary        0
# Make                0
# Price               0
# dtype: int64

# %% [markdown]
# # ***Analysis***

# %% [markdown]
# ***Geographic analysis***

# %%
for x in ['Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules','Two Wheelers (Category L2 (CMVR))','Two Wheelers (Max power not exceeding 250 Watts)','Three Wheelers (Category L5 slow speed as per CMVR)','Three Wheelers (Category L5 as per CMVR)','Passenger Cars (Category M1 as per CMVR)','Buses','Total in state']:
    plt.figure(figsize=(15,10))
    sns.barplot(data=ev_data, x=x, y='State')

# %% [markdown]
# **Observations** -
#
# From the above graph we can see that Maharashtra has the highest count of customers for electric vehicles.
#
# Meghalaya has the least customer count for EVs.
#
# At last the takeway from this analysis is that the focus for our marketing should be Maharashtra, Gujarat, UP, Haryana.
#
# From the above plot we can see that uttarpradesh and maharastra has highest target customers.

# %% [markdown]
# **Demographic Analysis**

# %%
for x in ['Age', 'No of Dependents' ,'Salary'  ,'Wife Salary'  ,'Total Salary'  ,'Price']:
    plt.figure(figsize=(12,5))
    sns.histplot(customer_data[x], kde=True)
    plt.title('histplot of {}'.format(x))
plt.show()

# %% [markdown]
# *observations:*
#
# People of age 30-40 cover the most of the consumer market for electric vehicles.
#
# The number of dependents dont effect the market that much
#
# people with medium pay grade lean more towards electric vehicles as we can see the middle class count is high.
#
# wife salary doesn't affect the market.
#
# People mostly spent around 70k to 1.8k on an electric vehicle.

# %%
plt.figure(figsize = (12,6))
sns.heatmap(customer_data.corr(), annot=True, cmap="crest")
# Out:
# <ipython-input-18-4a1f4b213e67>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(customer_data.corr(), annot=True, cmap="crest")
# <Axes: >

# %%
sns.pairplot(customer_data)

# %% [markdown]
# # ***The Model***

# %% [markdown]
# **Importing machine learning libraries**

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# **The k_means model for demographic segmentation:-**

# %%
X_scaled = StandardScaler().fit_transform(customer_data[['Age', 'Salary', 'Total Salary','Price']])
X_scaled = pd.DataFrame(X_scaled,columns=['Age', 'Salary', 'Total Salary','Price'])
x = X_scaled.to_numpy()
X_scaled
# Out:
#          Age    Salary  Total Salary     Price
# 0  -1.498630 -1.397118     -1.406760 -0.904843
# 1  -0.211304 -0.501877     -0.258937 -0.445579
# 2   1.397855  0.094950     -0.450240  0.013685
# 3   0.754191 -0.203464     -0.067633  0.013685
# 4  -0.854967  0.094950      0.314975  0.932213
# ..       ...       ...           ...       ...
# 94 -1.498630  0.990190      0.123671  0.932213
# 95  2.202434  3.079085      2.706274  0.932213
# 96  2.363350  0.691777     -0.067633 -0.215947
# 97  2.363350  1.437811      1.654102  0.702581
# 98  2.363350  0.691777     -0.067633 -0.215947
#
# [99 rows x 4 columns]

# %%
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++',
                    max_iter=300, n_init=10, random_state=0)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(10,6))
plt.plot(range(1, 11), wcss , linestyle='dashed', marker='o', markersize=10)
plt.title('Elbow Method')
plt.xlabel('k values')
plt.ylabel('WCSS') #within cluster sum of squares
plt.tight_layout()
plt.show()

# %% [markdown]
# **We will keep k as 4, hence K = 4**

# %%
kmeans = KMeans(n_clusters = 4)
label = kmeans.fit_predict(X_scaled)
print(label)
# Out:
# [0 0 1 2 2 0 0 0 2 0 2 0 0 0 0 3 0 0 0 0 2 0 2 0 2 2 0 0 2 2 0 2 2 2 1 3 0
#  2 2 0 0 0 2 2 0 2 0 2 0 2 1 3 1 3 3 1 1 0 0 0 0 2 2 0 0 0 2 2 3 2 2 2 0 2
#  2 2 0 2 1 3 1 3 1 1 1 1 0 2 3 0 0 3 1 0 2 3 1 3 1]
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
labels = pd.DataFrame(label,columns=['K value'])
labels.head()
# Out:
#    K value
# 0        0
# 1        0
# 2        1
# 3        2
# 4        2

# %%
final = customer_data[['Age', 'Salary', 'Total Salary','Price']].copy()
final = pd.concat([final,labels],axis=1) #the final dataset including all the relevent information.
final.head()
# Out:
#    Age   Salary  Total Salary    Price  K value
# 0   27   800000        800000   800000        0
# 1   35  1400000       2000000  1000000        0
# 2   45  1800000       1800000  1200000        1
# 3   41  1600000       2200000  1200000        2
# 4   31  1800000       2600000  1600000        2

# %%
print(kmeans.cluster_centers_) #These are the centroids for all the clusters.
# Out:
# [[-0.70642931 -0.81559401 -0.8328483  -0.85126212]
#  [ 1.23693897  1.03992584  0.15555519 -0.07816767]
#  [-0.15766502 -0.06329983  0.17294646  0.53557608]
#  [ 1.18330036  1.52484777  2.03671022  1.39147723]]

# %%
sns.pairplot(final,x_vars = ['Age','Salary','Total Salary','Price'], y_vars = ['Age','Salary','Total Salary','Price'], hue='K value')

# %% [markdown]
# ***So, in conclusion these are all the possible clusters or segments that we have using demographic segmentation.***
